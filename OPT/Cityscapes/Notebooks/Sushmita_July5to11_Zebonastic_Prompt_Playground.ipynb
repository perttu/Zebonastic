# %%
##1
import random

# Lists of specifications
markets = ["vibrant marketplaces", "bustling street bazaars", "colorful food markets", "trading squares"]
nights = ["glimmering nights", "enchanting moonlit evenings", "nocturnal wonderlands", "dazzling city lights"]
neon_lights = ["neon-lit streets", "brightly illuminated signs", "glowing skyscrapers"]
asian_people = ["crowded with locals", "flourishing with Asian faces", "diverse Asian community"]
smoke = ["hazy smoke-filled streets", "mysterious foggy alleys", "wafting smoke from food stalls"]
fast_life = ["hustle and bustle", "energetic and fast-paced vibe", "non-stop action"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    market = random.choice(markets)
    night = random.choice(nights)
    neon_light = random.choice(neon_lights)
    asian_person = random.choice(asian_people)
    city_smoke = random.choice(smoke)
    city_life = random.choice(fast_life)

    prompt = f"You are standing in a cityscape characterized by {market}, on a {night} with {neon_light} illuminating the surroundings. The city is full of {asian_person} going about their lives, and the air is filled with {city_smoke}. The energy of the city reflects the {city_life} it embodies."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# You are standing in a cityscape characterized by bustling street bazaars, on a enchanting moonlit evenings with glowing skyscrapers illuminating the surroundings. The city is full of crowded with locals going about their lives, and the air is filled with mysterious foggy alleys. The energy of the city reflects the hustle and bustle it embodies.
#
# Prompt 2:
# You are standing in a cityscape characterized by trading squares, on a enchanting moonlit evenings with brightly illuminated signs illuminating the surroundings. The city is full of flourishing with Asian faces going about their lives, and the air is filled with wafting smoke from food stalls. The energy of the city reflects the hustle and bustle it embodies.
#
# Prompt 3:
# ...

# %%
##2
import random

# Lists of specifications
mountains = ["majestic mountains", "towering peaks", "rolling hills"]
bridges = ["iconic bridges", "suspension bridges", "arched bridges"]
highways = ["busy highways", "expressways", "traffic-filled roads"]
buildings = ["skyscrapers", "modern buildings", "architectural marvels"]
sunsets = ["vibrant sunsets", "golden hour skies", "painted horizons"]
bikers = ["cyclists", "biking enthusiasts", "bicycle riders"]
cars = ["cars", "automobiles", "vehicles"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    mountain = random.choice(mountains)
    bridge = random.choice(bridges)
    highway = random.choice(highways)
    building = random.choice(buildings)
    sunset = random.choice(sunsets)
    biker = random.choice(bikers)
    car = random.choice(cars)

    prompt = f"You find yourself in a cityscape nestled among {mountain} with a magnificent {bridge} spanning a river. A bustling {highway} passes through the city, surrounded by towering {building}. As the sun sets, the sky transforms into a canvas of {sunset} hues. {biker} pedal through the streets, alongside the stream of passing {car}."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# You find yourself in a cityscape nestled among majestic mountains with a magnificent iconic bridges spanning a river. A bustling busy highways passes through the city, surrounded by towering skyscrapers. As the sun sets, the sky transforms into a canvas of golden hour skies hues. bicycle riders pedal through the streets, alongside the stream of passing cars.
#
# Prompt 2:
# You find yourself in a cityscape nestled among rolling hills with a magnificent iconic bridges spanning a river. A bustling traffic-filled roads passes through the city, surrounded by towering modern buildings. As the sun sets, the sky transforms into a canvas of golden hour skies hues. bicycle riders pedal through the streets, alongside the stream of passing vehicles.
#
# Prompt 3:
# ...

# %%
##3
import random

# Lists of specifications
futuristic = ["futuristic", "high-tech", "ultramodern"]
greenery = ["lush greenery", "beautiful parks", "vertical gardens"]
skyscrapers = ["gleaming skyscrapers", "towering high-rises", "modern architectural wonders"]
people = ["people strolling", "crowds of pedestrians", "locals going about their day"]
daytime = ["bright daylight", "sunshine-filled skies", "clear sunny weather"]
traffic_lights = ["illuminated traffic lights", "colorful signals", "glowing intersections"]
cars = ["cars", "automobiles", "vehicles"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    future = random.choice(futuristic)
    green = random.choice(greenery)
    skyscraper = random.choice(skyscrapers)
    person = random.choice(people)
    day = random.choice(daytime)
    traffic_light = random.choice(traffic_lights)
    car = random.choice(cars)

    prompt = f"You step into a cityscape characterized by {future} elements, where {green} blends seamlessly with {skyscraper}. The streets are filled with {person}, creating a vibrant atmosphere. It's a beautiful {day} scene, with {traffic_light} guiding the flow of {car} through the city."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# You step into a cityscape characterized by ultramodern elements, where vertical gardens blends seamlessly with gleaming skyscrapers. The streets are filled with locals going about their day, creating a vibrant atmosphere. It's a beautiful bright daylight scene, with glowing intersections guiding the flow of cars through the city.
#
# Prompt 2:
# You step into a cityscape characterized by high-tech elements, where beautiful parks blends seamlessly with towering high-rises. The streets are filled with locals going about their day, creating a vibrant atmosphere. It's a beautiful sunshine-filled skies scene, with glowing intersections guiding the flow of cars through the city.
#
# Prompt 3:
# ...

# %%
##4
import random

# Lists of specifications
futuristic = ["futuristic", "high-tech", "modern"]
trees = ["lush trees", "tall trees", "leafy canopies"]
streets = ["busy streets", "vibrant avenues", "lively boulevards"]
colorful_lights = ["colorful lights", "vibrant neon signs", "illuminated pathways"]
cloudy = ["cloudy skies", "overcast atmosphere", "misty air"]
water_body = ["glistening river", "calm lake", "serene waterfront"]
moon = ["full moon", "radiant moon", "glowing moon"]
reflection = ["reflecting in the water", "creating shimmering reflections", "dancing on the surface"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    future = random.choice(futuristic)
    tree = random.choice(trees)
    street = random.choice(streets)
    light = random.choice(colorful_lights)
    clouds = random.choice(cloudy)
    water = random.choice(water_body)
    lunar = random.choice(moon)
    reflect = random.choice(reflection)

    prompt = f"You enter a {future} cityscape with {tree} lining the {street}. The city is adorned with {light}, casting a colorful glow all around. The sky is filled with {clouds}, and a {water} adds tranquility to the scene. The {lunar} shines above, {reflect} and creating a mesmerizing ambiance."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# You enter a futuristic cityscape with lush trees lining the vibrant avenues. The city is adorned with vibrant neon signs, casting a colorful glow all around. The sky is filled with cloudy skies, and a serene waterfront adds tranquility to the scene. The full moon shines above, dancing on the surface and creating a mesmerizing ambiance.
#
# Prompt 2:
# You enter a futuristic cityscape with leafy canopies lining the lively boulevards. The city is adorned with colorful lights, casting a colorful glow all around. The sky is filled with misty air, and a calm lake adds tranquility to the scene. The full moon shines above, creating shimmering reflections and creating a mesmerizing ambiance.
#
# Prompt 3:
# ...

# %%
##5
import random

# Lists of specifications
fresh_produce = ["fresh fruits", "crisp vegetables", "farm-to-table produce"]
canals = ["meandering canals", "serene waterways", "navigable channels"]
streets = ["busy streets", "lively avenues", "vibrant boulevards"]
rivers = ["majestic rivers", "glistening water bodies", "rippling streams"]
local_crafts = ["handcrafted goods", "artisanal creations", "traditional artworks"]
colorful_boats = ["colorful boats", "vibrant vessels", "painted barges"]
floating_markets = ["floating markets", "aquatic bazaars", "waterborne marketplaces"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    produce = random.choice(fresh_produce)
    canal = random.choice(canals)
    street = random.choice(streets)
    river = random.choice(rivers)
    craft = random.choice(local_crafts)
    boat = random.choice(colorful_boats)
    market = random.choice(floating_markets)

    prompt = f"Immerse yourself in a bustling cityscape where {fresh_produce} fill the air with their aroma. Meandering {canals} interlace the {streets}, offering a picturesque view. A {rivers} flows gracefully through the city, reflecting the vibrant surroundings. Explore the {local_crafts} showcased in colorful {colorful_boats} at the {market}."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# Immerse yourself in a bustling cityscape where ['fresh fruits', 'crisp vegetables', 'farm-to-table produce'] fill the air with their aroma. Meandering ['meandering canals', 'serene waterways', 'navigable channels'] interlace the ['busy streets', 'lively avenues', 'vibrant boulevards'], offering a picturesque view. A ['majestic rivers', 'glistening water bodies', 'rippling streams'] flows gracefully through the city, reflecting the vibrant surroundings. Explore the ['handcrafted goods', 'artisanal creations', 'traditional artworks'] showcased in colorful ['colorful boats', 'vibrant vessels', 'painted barges'] at the floating markets.
#
# Prompt 2:
# ...

# %%
##6
import random

# Lists of specifications
recreational_facilities = ["parks", "playgrounds", "sports arenas"]
tranquil_surface = ["calm waters", "serene lakes", "peaceful ponds"]
beauty = ["stunning landscapes", "breathtaking vistas", "scenic views"]
efficient_transportation = ["modern transit systems", "high-speed trains", "efficient buses"]
underground_tunnels = ["subterranean passageways", "underground walkways", "subway networks"]
shopping = ["vibrant markets", "shopping districts", "boutiques"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    facility = random.choice(recreational_facilities)
    surface = random.choice(tranquil_surface)
    scenic = random.choice(beauty)
    transportation = random.choice(efficient_transportation)
    tunnel = random.choice(underground_tunnels)
    shop = random.choice(shopping)

    prompt = f"Explore a cityscape that offers an array of {recreational_facilities}, providing spaces for leisure and enjoyment. The city is adorned with {tranquil_surface}, adding to its natural {beauty}. Experience {efficient_transportation} that seamlessly connects different parts of the city, including an extensive network of {underground_tunnels}. Indulge in a day of {shopping} and discover unique treasures in every corner."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# Explore a cityscape that offers an array of ['parks', 'playgrounds', 'sports arenas'], providing spaces for leisure and enjoyment. The city is adorned with ['calm waters', 'serene lakes', 'peaceful ponds'], adding to its natural ['stunning landscapes', 'breathtaking vistas', 'scenic views']. Experience ['modern transit systems', 'high-speed trains', 'efficient buses'] that seamlessly connects different parts of the city, including an extensive network of ['subterranean passageways', 'underground walkways', 'subway networks']. Indulge in a day of ['vibrant markets', 'shopping districts', 'boutiques'] and discover unique treasures in every corner.
#
# Prompt 2:
# ...

# %%
##7
import random

# Lists of specifications
sunny = ["sunny", "sun-drenched", "radiant"]
fall_season = ["autumnal", "fall-colored", "crisp"]
lush_green_rooftop = ["lush green rooftop", "verdant elevated", "foliage-covered"]
rooftop_gardens = ["rooftop gardens", "green sanctuaries", "elevated oases"]
vibrant = ["vibrant", "colorful", "lively"]
eco_friendly = ["eco-friendly", "sustainable", "environmentally conscious"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    sunny_weather = random.choice(sunny)
    fall = random.choice(fall_season)
    rooftop = random.choice(lush_green_rooftop)
    gardens = random.choice(rooftop_gardens)
    vibrant_env = random.choice(vibrant)
    eco = random.choice(eco_friendly)

    prompt = f"Step into a cityscape basking in {sunny_weather} hues during the {fall} season. Above, a {lush_green_rooftop} creates a serene and enchanting atmosphere. Explore the {rooftop_gardens} nestled amidst the city's architecture, offering a glimpse of nature's beauty. Immerse yourself in the {vibrant} and {eco_friendly} environment that seamlessly combines urban living and sustainable practices."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# Step into a cityscape basking in radiant hues during the autumnal season. Above, a ['lush green rooftop', 'verdant elevated', 'foliage-covered'] creates a serene and enchanting atmosphere. Explore the ['rooftop gardens', 'green sanctuaries', 'elevated oases'] nestled amidst the city's architecture, offering a glimpse of nature's beauty. Immerse yourself in the ['vibrant', 'colorful', 'lively'] and ['eco-friendly', 'sustainable', 'environmentally conscious'] environment that seamlessly combines urban living and sustainable practices.
#
# Prompt 2:
# ...

# %%
##8
import random

# Lists of specifications
seasons = ["spring", "summer", "autumn", "winter"]
times_of_day = ["morning", "afternoon", "evening", "night"]
sustainability = ["sustainable", "environmentally friendly", "green"]
technology = ["advanced technology", "innovative solutions", "smart infrastructure"]
floating_platforms = ["floating platforms", "levitating structures", "hovering walkways"]
artificial_islands = ["artificial islands", "man-made landmasses", "engineered archipelagos"]
futuristic = ["futuristic", "high-tech", "ultramodern"]
floating_cities = ["floating cities", "aquatic metropolises", "levitating urban hubs"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    season = random.choice(seasons)
    time_of_day = random.choice(times_of_day)
    sustainable = random.choice(sustainability)
    tech = random.choice(technology)
    floating_platform = random.choice(floating_platforms)
    artificial_island = random.choice(artificial_islands)
    future = random.choice(futuristic)
    floating_city = random.choice(floating_cities)

    prompt = f"Imagine a cityscape in the midst of {season}, during {time_of_day}. This {sustainable} city seamlessly integrates {tech}, with {floating_platform} and {artificial_island} dotting the landscape. Step into a {future} world where {floating_city} rise above the water, showcasing architectural marvels and pushing the boundaries of urban design."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# Imagine a cityscape in the midst of winter, during morning. This sustainable city seamlessly integrates advanced technology, with hovering walkways and artificial islands dotting the landscape. Step into a ultramodern world where floating cities rise above the water, showcasing architectural marvels and pushing the boundaries of urban design.
#
# Prompt 2:
# Imagine a cityscape in the midst of spring, during morning. This green city seamlessly integrates innovative solutions, with levitating structures and man-made landmasses dotting the landscape. Step into a high-tech world where aquatic metropolises rise above the water, showcasing architectural marvels and pushing the boundaries of urban design.
#
# Prompt 3:
# ...

# %%
##9
import random

# Lists of specifications
seasons = ["spring", "summer", "autumn", "winter"]
times_of_day = ["morning", "afternoon", "evening", "night"]
art_installations = ["art installations", "public artworks", "sculptures"]
murals = ["vibrant murals", "street art", "colorful paintings"]
transforming_streets = ["transforming streets", "metamorphosing pathways", "evolving roadways"]
open_air_gallery = ["open-air gallery", "street gallery", "outdoor exhibition"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    season = random.choice(seasons)
    time_of_day = random.choice(times_of_day)
    art_installation = random.choice(art_installations)
    mural = random.choice(murals)
    transforming_street = random.choice(transforming_streets)
    gallery = random.choice(open_air_gallery)

    prompt = f"Imagine a cityscape in the midst of {season}, during {time_of_day}. The streets are adorned with captivating {art_installation}, including {murals} that bring color and creativity to the urban environment. Witness the magic of {transforming_street}, where the cityscape evolves into a living canvas. Explore the city's {gallery}, where the streets themselves become an open-air gallery showcasing the work of talented artists."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# Imagine a cityscape in the midst of summer, during evening. The streets are adorned with captivating sculptures, including ['vibrant murals', 'street art', 'colorful paintings'] that bring color and creativity to the urban environment. Witness the magic of transforming streets, where the cityscape evolves into a living canvas. Explore the city's outdoor exhibition, where the streets themselves become an open-air gallery showcasing the work of talented artists.
#
# Prompt 2:
# Imagine a cityscape in the midst of spring, during morning. The streets are adorned with captivating sculptures, including ['vibrant murals', 'street art', 'colorful paintings'] that bring color and creativity to the urban environment. Witness the magic of metamorphosing pathways, where the cityscape evolves into a living canvas. Explore the city's street gallery, where the streets themselves become an open-air gallery showcasing the work of talented artists.
#
# Prompt 3:
# ...

# %%
##10
import random

# Lists of specifications
seasons = ["spring", "summer", "autumn", "winter"]
times_of_day = ["morning", "afternoon", "evening", "night"]
pedestrian_zones = ["pedestrian zones", "car-free streets", "walkable areas"]
limited_cars = ["limited car traffic", "restricted vehicle access", "few automobiles"]
outdoor_activities = ["outdoor activities", "recreational pursuits", "leisurely pastimes"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    season = random.choice(seasons)
    time_of_day = random.choice(times_of_day)
    pedestrian_zone = random.choice(pedestrian_zones)
    car_limitation = random.choice(limited_cars)
    activities = random.choice(outdoor_activities)

    prompt = f"Imagine a cityscape in the midst of {season}, during {time_of_day}. The city has designated {pedestrian_zone} where cars are limited, allowing people to freely walk, cycle, and enjoy {activities} in a safe and pedestrian-friendly environment. Experience the joy of exploring the cityscape on foot or by bike, immersing yourself in the vibrant urban atmosphere."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# Imagine a cityscape in the midst of autumn, during evening. The city has designated pedestrian zones where cars are limited, allowing people to freely walk, cycle, and enjoy outdoor activities in a safe and pedestrian-friendly environment. Experience the joy of exploring the cityscape on foot or by bike, immersing yourself in the vibrant urban atmosphere.
#
# Prompt 2:
# Imagine a cityscape in the midst of summer, during afternoon. The city has designated pedestrian zones where cars are limited, allowing people to freely walk, cycle, and enjoy outdoor activities in a safe and pedestrian-friendly environment. Experience the joy of exploring the cityscape on foot or by bike, immersing yourself in the vibrant urban atmosphere.
#
# Prompt 3:
# ...

# %%
##11
import random

# Lists of specifications
seasons = ["spring", "summer", "autumn", "winter"]
times_of_day = ["morning", "afternoon", "evening", "night"]
nature_juxtaposition = ["juxtaposition of nature and urban environment", "blend of natural elements and cityscape", "harmony between urban and natural surroundings"]
urban_wildlife = ["squirrels", "birds", "deer", "urban wildlife", "city-dwelling animals"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    season = random.choice(seasons)
    time_of_day = random.choice(times_of_day)
    juxtaposition = random.choice(nature_juxtaposition)
    wildlife = random.choice(urban_wildlife)

    prompt = f"Imagine a cityscape in the midst of {season}, during {time_of_day}, where a beautiful {juxtaposition} exists. As you explore, you might spot {wildlife} roaming freely amidst the urban environment. These city-dwelling creatures bring a touch of nature and a sense of wonder to the vibrant cityscape."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# Imagine a cityscape in the midst of summer, during morning, where a beautiful blend of natural elements and cityscape exists. As you explore, you might spot urban wildlife roaming freely amidst the urban environment. These city-dwelling creatures bring a touch of nature and a sense of wonder to the vibrant cityscape.
#
# Prompt 2:
# Imagine a cityscape in the midst of summer, during night, where a beautiful harmony between urban and natural surroundings exists. As you explore, you might spot squirrels roaming freely amidst the urban environment. These city-dwelling creatures bring a touch of nature and a sense of wonder to the vibrant cityscape.
#
# Prompt 3:
# ...

# %%
##12
import random

# Lists of specifications
seasons = ["spring", "summer", "autumn", "winter"]
times_of_day = ["morning", "afternoon", "evening", "night"]
outdoor_cafes = ["outdoor cafes", "sidewalk cafes", "al fresco dining areas"]
ambiance = ["lively ambiance", "energetic atmosphere", "vibrant buzz"]
food = ["delicious food", "culinary delights", "gastronomic treats"]
city_life = ["vibrant city life", "urban hustle and bustle", "dynamic cityscape"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    season = random.choice(seasons)
    time_of_day = random.choice(times_of_day)
    cafe = random.choice(outdoor_cafes)
    ambiance_choice = random.choice(ambiance)
    food_choice = random.choice(food)
    city_life_choice = random.choice(city_life)

    prompt = f"Picture yourself in a cityscape during the {season}, in the {time_of_day}, where {outdoor_cafes} dot the streets. Immerse yourself in the {ambiance_choice}, as you enjoy {food_choice} at these delightful dining spots. The {city_life_choice} surrounds you, creating a dynamic and vibrant urban experience."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# Picture yourself in a cityscape during the spring, in the morning, where ['outdoor cafes', 'sidewalk cafes', 'al fresco dining areas'] dot the streets. Immerse yourself in the energetic atmosphere, as you enjoy delicious food at these delightful dining spots. The dynamic cityscape surrounds you, creating a dynamic and vibrant urban experience.
#
# Prompt 2:
# Picture yourself in a cityscape during the winter, in the night, where ['outdoor cafes', 'sidewalk cafes', 'al fresco dining areas'] dot the streets. Immerse yourself in the energetic atmosphere, as you enjoy gastronomic treats at these delightful dining spots. The vibrant city life surrounds you, creating a dynamic and vibrant urban experience.
#
# Prompt 3:
# ...

# %%
##13
import random

# Lists of specifications
seasons = ["spring", "summer", "autumn", "winter"]
times_of_day = ["morning", "afternoon", "evening", "night"]
landscapes = ["lush parks", "expansive gardens", "scenic mountains", "serene lakes"]
water_features = ["urban water features", "fountains", "cascading waterfalls", "reflecting pools"]
appeal = ["visual appeal", "aesthetic charm", "captivating beauty"]
tranquility = ["sense of tranquility", "calming atmosphere", "peaceful serenity"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    season = random.choice(seasons)
    time_of_day = random.choice(times_of_day)
    landscape = random.choice(landscapes)
    water_feature = random.choice(water_features)
    visual_appeal = random.choice(appeal)
    sense_of_tranquility = random.choice(tranquility)

    prompt = f"Imagine a cityscape in the midst of {season}, during {time_of_day}, where {landscape} and {water_feature} enhance the urban environment. Experience the {visual_appeal} of cascading waterfalls and the serenity of reflecting pools. These elements create a {sense_of_tranquility}, offering a peaceful escape amidst the vibrant cityscape."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# Imagine a cityscape in the midst of autumn, during morning, where scenic mountains and fountains enhance the urban environment. Experience the visual appeal of cascading waterfalls and the serenity of reflecting pools. These elements create a calming atmosphere, offering a peaceful escape amidst the vibrant cityscape.
#
# Prompt 2:
# Imagine a cityscape in the midst of summer, during afternoon, where scenic mountains and fountains enhance the urban environment. Experience the captivating beauty of cascading waterfalls and the serenity of reflecting pools. These elements create a calming atmosphere, offering a peaceful escape amidst the vibrant cityscape.
#
# Prompt 3:
# ...

# %%
##14
import random

# Lists of specifications
seasons = ["spring", "summer", "autumn", "winter"]
times_of_day = ["morning", "afternoon", "evening", "night"]
landscapes = ["lush parks", "expansive gardens", "majestic mountains", "picturesque waterfronts"]
architectural_marvels = ["Architectural Marvels", "iconic skyscrapers", "modern landmarks", "avant-garde designs", "unique structures"]
design = ["unique design", "innovative architecture", "distinctive style"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    season = random.choice(seasons)
    time_of_day = random.choice(times_of_day)
    landscape = random.choice(landscapes)
    marvel = random.choice(architectural_marvels)
    unique_design = random.choice(design)

    prompt = f"Imagine a cityscape in the midst of {season}, during {time_of_day}, where {landscape} serve as the backdrop for {architectural_marvels} that define the skyline. Witness the {unique_design} and marvel at the innovative architecture showcased in these structures. Explore the cityscape and immerse yourself in the blend of natural beauty and extraordinary design."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# Imagine a cityscape in the midst of spring, during night, where lush parks serve as the backdrop for ['Architectural Marvels', 'iconic skyscrapers', 'modern landmarks', 'avant-garde designs', 'unique structures'] that define the skyline. Witness the unique design and marvel at the innovative architecture showcased in these structures. Explore the cityscape and immerse yourself in the blend of natural beauty and extraordinary design.
#
# Prompt 2:
# Imagine a cityscape in the midst of summer, during night, where picturesque waterfronts serve as the backdrop for ['Architectural Marvels', 'iconic skyscrapers', 'modern landmarks', 'avant-garde designs', 'unique structures'] that define the skyline. Witness the innovative architecture and marvel at the innovative architecture showcased in these structures. Explore the cityscape and immerse yourself in the blend of natural beauty and extraordinary design.
#
# Prompt 3:
# ...

# %%
##15
import random

# Lists of specifications
seasons = ["spring", "summer", "autumn", "winter"]
times_of_day = ["morning", "afternoon", "evening", "night"]
landscapes = ["lush parks", "expansive gardens", "majestic mountains", "picturesque waterfronts"]
historic_buildings = ["historic buildings", "architectural treasures", "time-honored structures"]
monuments = ["iconic monuments", "landmarks", "monumental structures"]
aesthetics = ["unique aesthetics", "distinctive styles", "artistic designs"]
engineering_feats = ["engineering feats", "remarkable constructions", "technical accomplishments"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    season = random.choice(seasons)
    time_of_day = random.choice(times_of_day)
    landscape = random.choice(landscapes)
    historic_building = random.choice(historic_buildings)
    monument = random.choice(monuments)
    aesthetic = random.choice(aesthetics)
    engineering_feat = random.choice(engineering_feats)

    prompt = f"Imagine a cityscape in the midst of {season}, during {time_of_day}, where {landscape} provide a stunning backdrop for {historic_building}, {monument}, and modern structures. Marvel at the {aesthetic} and architectural prowess showcased in these buildings. Explore the cityscape and appreciate the blend of rich history, unique aesthetics, and remarkable {engineering_feat}."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# Imagine a cityscape in the midst of spring, during night, where majestic mountains provide a stunning backdrop for architectural treasures, iconic monuments, and modern structures. Marvel at the unique aesthetics and architectural prowess showcased in these buildings. Explore the cityscape and appreciate the blend of rich history, unique aesthetics, and remarkable remarkable constructions.
#
# Prompt 2:
# Imagine a cityscape in the midst of summer, during morning, where lush parks provide a stunning backdrop for historic buildings, landmarks, and modern structures. Marvel at the distinctive styles and architectural prowess showcased in these buildings. Explore the cityscape and appreciate the blend of rich history, unique aesthetics, and remarkable engineering feats.
#
# Prompt 3:
# ...

# %%
##16
import random

# Lists of specifications
seasons = ["spring", "summer", "autumn", "winter"]
times_of_day = ["morning", "afternoon", "evening", "night"]
landscapes = ["lush parks", "expansive gardens", "majestic mountains", "picturesque waterfronts"]
rooftop_bars = ["Rooftop Bars", "sky-high lounges", "elevated establishments"]
panoramic_views = ["panoramic views", "breathtaking vistas", "stunning panoramas"]
dine_drink = ["dine", "enjoy a drink", "savor culinary delights"]
elevated_bars = ["Elevated bars", "rooftop restaurants", "sky-high bistros"]
visitors = ["visitors", "guests", "patrons"]

# Generate 10 prompts
prompts = []
for _ in range(10):
    season = random.choice(seasons)
    time_of_day = random.choice(times_of_day)
    landscape = random.choice(landscapes)
    rooftop_bar = random.choice(rooftop_bars)
    view = random.choice(panoramic_views)
    dining = random.choice(dine_drink)
    elevated_bar = random.choice(elevated_bars)
    visitor = random.choice(visitors)

    prompt = f"Imagine a cityscape in the midst of {season}, during {time_of_day}, where {landscape} serve as the backdrop for {rooftop_bar} with {view}. Sit back and {dining} at {elevated_bar}, while taking in the {panoramic_views} of the city. These establishments offer a remarkable experience for {visitors} to enjoy the urban landscape from a new perspective."
    prompts.append(prompt)

# Print the prompts
for i, prompt in enumerate(prompts):
    print(f"Prompt {i+1}:")
    print(prompt)
    print()
# Out:
# Prompt 1:
# Imagine a cityscape in the midst of spring, during afternoon, where majestic mountains serve as the backdrop for elevated establishments with stunning panoramas. Sit back and dine at sky-high bistros, while taking in the ['panoramic views', 'breathtaking vistas', 'stunning panoramas'] of the city. These establishments offer a remarkable experience for ['visitors', 'guests', 'patrons'] to enjoy the urban landscape from a new perspective.
#
# Prompt 2:
# Imagine a cityscape in the midst of autumn, during evening, where majestic mountains serve as the backdrop for Rooftop Bars with stunning panoramas. Sit back and enjoy a drink at Elevated bars, while taking in the ['panoramic views', 'breathtaking vistas', 'stunning panoramas'] of the city. These establishments offer a remarkable experience for ['visitors', 'guests', 'patrons'] to enjoy the urban landscape from a new perspective.
#
# Prompt 3:
# ...
