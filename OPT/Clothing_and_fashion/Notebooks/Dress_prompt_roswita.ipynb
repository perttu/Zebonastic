# %%
import random
import csv
import os
from google.colab import files

# Define the options for each category
female_singers = [
    "Beyoncé",
    "Taylor Swift",
    "Adele",
    "Rihanna",
    "Billie Eilish",
    "Ariana Grande",
    "Dua Lipa",
    "Lady Gaga",
    "Katy Perry",
    "Sia",
    "Lizzo",
    "Shakira",
    "Miley Cyrus",
    "Selena Gomez",
    "Lana Del Rey",
    "Camila Cabello",
    "Halsey",
    "Jennifer Lopez",
    "Pink",
    "Demi Lovato"
]


dress_styles = [
    'Boho dress',
    'Ruffled dress',
    'Embroidered dress',
    'Kimono dress',
    'Smocked dress',
    'Balloon sleeve dress',
    'Lace dress',
    'Cutout dress',
    'Cold shoulder dress',
    'Asymmetric dress',
    'Tiered ruffle dress',
    'Bell sleeve dress',
    'Puff sleeve dress',
    'Peasant dress',
    'Polka dot dress',
    'Floral dress',
    'Striped dress',
    'Jacquard dress',
    'Sequin dress',
    'Velvet dress',
    'Chiffon dress',
    'Satin dress',
    'Leather dress',
    'Plaid dress',
    'Geometric print dress',
    'Tie-dye dress',
    'Animal print dress',
    'Ombre dress',
    'Metallic dress',
    'Fringe dress',
]

dress_brands = [
    'Gucci',
    'Versace',
    'Chanel',
    'Prada',
    'Dior',
    'Valentino',
    'Louis Vuitton',
    'Balenciaga',
    'Givenchy',
    'Saint Laurent',
    'Alexander McQueen',
    'Hermès',
    'Burberry',
    'Fendi',
    'Ralph Lauren',
    'Calvin Klein',
    'Michael Kors',
    'Tom Ford',
    'Marc Jacobs',
    'Victoria Beckham',
    'Stella McCartney',
    'Roberto Cavalli',
    'Christian Louboutin',
    'Jimmy Choo',
    'Dolce & Gabbana',
    'Miu Miu',
    'Moschino',
    'Isabel Marant',
    'Celine',
    'Zimmermann',
]

colors = [
    'Red',
    'Orange',
    'Yellow',
    'Green',
    'Blue',
    'Purple',
    'Pink',
    'Brown',
    'Black',
    'White',
    'Gray',
    'Beige',
    'Teal',
    'Navy',
    'Magenta',
    'Turquoise',
    'Lime',
    'Indigo',
    'Cyan',
    'Maroon',
    'Olive',
    'Silver',
    'Gold',
    'Violet',
    'Coral',
    'Slate',
    'Mint',
    'Peach',
    'Lavender',
    'Periwinkle',
]

pastel_colors = [
    "Apricot", "Baby Blue", "Baby Pink", "Cotton Candy", "Lavender", "Lilac",
    "Mauve", "Peach", "Pale Yellow", "Mint Green", "Sky Blue", "Periwinkle",
    "Lavender Blush", "Peach Puff", "Lemon Chiffon", "Seafoam Green", "Powder Blue",
    "Orchid", "Pink Lemonade", "Pale Lavender", "Light Salmon", "Pale Gold",
    "Celadon", "Cornflower Blue", "Plum", "Coral", "Light Apricot", "Buttercup",
    "Baby Mint", "Wisteria", "Sweet Pink", "Champagne", "Canary Yellow",
    "Honeydew Green", "Alice Blue", "French Lilac", "Rose Quartz", "Apricot Sorbet",
    "Banana Cream", "Turquoise", "Blush Pink", "Mint Cream", "Aqua Marine",
    "Pistachio", "Baby Powder"]
photography_boosters = [
    'Feminine beauty',
    'Cinematic',
    'Moody',
    'Minimalist',
    'Vibrant',
    'Vintage',
    'Black and white',
    'Dreamy',
    'Street style',
    'Natural light',
    'Macro',
    'Dramatic',
    'Documentary',
    'Fashion editorial',
    'Bokehlicious',
    'Urban',
    'Pastel tones',
    'Film-inspired',
    'Fine art',
    'Golden hour',
    'Adventure',
    'Architectural',
    'Travel',
    'Contrast',
    'Silhouette',
    'Abstract',
    'Gritty',
    'Underwater',
    'Long exposure',
    'Night',
]

fashion_styles = [
    'Bohemian style',
    'Classic style',
    'Street style',
    'Casual style',
    'Vintage style',
    'Minimalist style',
    'Glamorous style',
    'Sporty style',
    'Preppy style',
    'Edgy style',
    'Romantic style',
    'Sophisticated style',
    'Eclectic style',
    'Retro style',
    'Chic style',
    'Hipster style',
    'Modern style',
    'Ethnic style',
    'Tomboy style',
    'Avant-garde style',
    'Country style',
    'Punk style',
    'Gothic style',
    'Business formal style',
    'Artistic style',
    'Effortless style',
    'Futuristic style',
    'Boho-chic style',
    'Rockabilly style',
    'Casual chic style',
]


photography_styles = [
    'Monochrome',
    'Portrait',
    'Close-up',
    'Landscape',
    'Street',
    'Abstract',
    'Still life',
    'Macro',
    'Black and white',
    'Fine art',
    'Documentary',
    'Fashion',
    'Wildlife',
    'Architectural',
    'Night',
    'Conceptual',
    'Candid',
    'Long exposure',
    'Travel',
    'Underwater',
    'Aerial',
    'Food',
    'Sports',
    'Event',
    'HDR',
    'Nature',
    'Astrophotography',
    'Film',
    'Experimental',
    'Product',
]



# Generate random prompts
num_prompts = 150
prompts = []


for _ in range(num_prompts):
    dress_brand = random.choice(dress_brands)
    color = random.choice(colors)
    pastel_color=random.choice(pastel_colors)
    dress_style = random.choice(dress_styles)
    photography_style = random.choice(photography_styles)
    female_singer=random.choice(female_singers)
    photography_booster=random.choice(photography_boosters)
    fashion_style=random.choice(fashion_styles)


    prompt = f"Ah9 Create a picture of {female_singer} wearing {dress_style} with combination of {color} and {pastel_color}  from {dress_brand} with fashion style as {fashion_style} in photography styles {photography_style} and photography booster {photography_booster} upscaled by Roswita."
    prompts.append(prompt)
    print(prompt)  # Print each prompt to check if they are generated correctly

# Open a new file for writing
with open('dress_prompts.csv', 'w') as file:
    # Write each prompt on a new line in the file
    for prompt in prompts:
        file.write(prompt + '\n')
# Download the file
files.download('dress_prompts.csv')
# Out:
# Ah9 Create a picture of Taylor Swift wearing Polka dot dress with combination of Slate and French Lilac  from Givenchy with fashion style as Ethnic style in photography styles Wildlife and photography booster Fashion editorial upscaled by Roswita.
# Ah9 Create a picture of Taylor Swift wearing Kimono dress with combination of Cyan and Mint Cream  from Dior with fashion style as Futuristic style in photography styles Long exposure and photography booster Fashion editorial upscaled by Roswita.
# Ah9 Create a picture of Pink wearing Boho dress with combination of Magenta and Pink Lemonade  from Gucci with fashion style as Avant-garde style in photography styles Long exposure and photography booster Long exposure upscaled by Roswita.
# Ah9 Create a picture of Katy Perry wearing Tiered ruffle dress with combination of Cyan and Baby Blue  from Dolce & Gabbana with fashion style as Boho-chic style in photography styles Landscape and photography booster Moody upscaled by Roswita.
# ...
